# %% [markdown]
# <a href="https://colab.research.google.com/github/Jullian29t/programacion1/blob/main/piton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LISTAS

# %%
cubos = [1, 8, 27, 65, 125]
cubos[3] = 64
print(cubos)
# Out:
# [1, 8, 27, 64, 125]

# %%
cubos = [1, 8, 27, 65, 123]
cubos[3:] = 64, 125
print(cubos)
# Out:
# [1, 8, 27, 64, 125]

# %%
cubos.append(6**3)
print(cubos)
# Out:
# [1, 8, 27, 64, 125, 216]

# %%
letras = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
letras
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
letras[2:5] = ["C", "D", "E"]
letras
# Out:
# ['a', 'b', 'C', 'D', 'E', 'f', 'g']

# %%
letras[2:5] = [ ]
letras
# Out:
# ['a', 'b', 'f', 'g']

# %%
a = ["a", "b", "c"]
n = [1, 2, 3]
x = [a, n, 5]
x
# Out:
# [['a', 'b', 'c'], [1, 2, 3], 5]

# %%
x[0]
# Out:
# ['a', 'b', 'c']

# %%
x[1][2]
# Out:
# 3

# %%
i = 256*256
print("El valor de i es",i)
# Out:
# El valor de i es 65536

# %% [markdown]
# QUIZ

# %%
hola_mundo = "hola mundo"
print (hola_mundo)
# Out:
# hola mundo

# %%
cadena = "hola mundo"
lista = ["h", "o", "l", "a", " ", "m", "u", "n", "d", "o"]
tupla = ("h", "o", "l", "a", " ", "m", "u", "n", "d", "o")
print(cadena)
print(lista)
print(tupla)
# Out:
# hola mundo
# ['h', 'o', 'l', 'a', ' ', 'm', 'u', 'n', 'd', 'o']
# ('h', 'o', 'l', 'a', ' ', 'm', 'u', 'n', 'd', 'o')

# %% [markdown]
# DICCIONARIOS

# %%
alumno = {"nombre": "juan","edad": 16,"curso": "4° año"}
alumno
# Out:
# {'nombre': 'juan', 'edad': 16, 'curso': '4° año'}

# %%
alumno["curso"]
# Out:
# '4° año'

# %%
alumno["faltas"] = 2
alumno
# Out:
# {'nombre': 'juan', 'edad': 16, 'curso': '4° año', 'faltas': 2}

# %%
del alumno["faltas"]
alumno
# Out:
# {'nombre': 'juan', 'edad': 16, 'curso': '4° año'}

# %%
alumno["años"] = alumno["edad"]
alumno
# Out:
# {'nombre': 'juan', 'edad': 16, 'curso': '4° año', 'años': 16}

# %% [markdown]
# CONJUNTOS

# %%
colores = {"rojo", "azul", "verde"}
colores
# Out:
# {'azul', 'rojo', 'verde'}

# %%
colores1 = {"rojo", "azul", "verde", "azul", "rojo"}
colores1
# Out:
# {'azul', 'rojo', 'verde'}

# %%
colores == colores1
# Out:
# True

# %%
for color in colores:
    print(color)
# Out:
# rojo
# azul
# verde

# %%
lista2= [("nombre", "ana"), ("edad", 16),]
diccionario2 = dict(lista2)
diccionario2
# Out:
# {'nombre': 'ana', 'edad': 16}

# %%
lista = ["Ana", "luis", "sofia"]
diccionario = dict(enumerate(lista))
diccionario
# Out:
# {0: 'Ana', 1: 'luis', 2: 'sofia'}

# %%
alumno4 = {"nombre": "juan","edad": 16,"curso": "4° año"}
print(list(alumno4), tuple(alumno4))
# Out:
# ['nombre', 'edad', 'curso'] ('nombre', 'edad', 'curso')

# %%
alumno4.values()
# Out:
# dict_values(['juan', 16, '4° año'])

# %%
list(alumno4.values())
# Out:
# ['juan', 16, '4° año']
