# %% [markdown]
# <a href="https://colab.research.google.com/github/Jullian29t/programacion1/blob/main/Parcial%20Programaci%C3%B3n%20Juli%C3%A1n%20Usma-2261346.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nombre: Julian Alexis Usma Forero

# %% [markdown]
# Parte II

# %% [markdown]
# **Instrucción 1:** Construya dos conjuntos A y B en Python con valores enteros de su elección. Los
# conjuntos deben cumplir que tengan al menos dos elementos en común y al menos un elemento
# diferente entre ellos. Una vez definidos los conjuntos, utilice el siguiente método:
# A.difference(B)
# Explique qué operación realiza esta sentencia sobre los conjuntos e indique cuál sería el conjunto
# resultante según los valores que usted haya definido. Haga el mismo ejercicio con la diferencia
# simétrica entre conjuntos con el método symmetric_difference.

# %%
A = {"rojo", "verde", "azul"}
B = {"rojo", "amarillo", "verde"}

# %%
A.difference(B)
# Out:
# {'azul'}

# %%
symmetric_difference
# Out:
# {'amarillo', 'azul'}

# %% [markdown]
# A.difference(B) lo q hace es mostar el valor del conjunto A q esta A q no aparece en el conjunto B. Y symmetric_difference nos dice los valores q no aparecen en los 2 conjuntos a la vez

# %% [markdown]
# **Instrucción 2:** Defina dos conjuntos A y B con valores de su elección, de manera que todos los
# elementos de B estén contenidos dentro del conjunto A. Posteriormente utilice el siguiente método:
# A.issuperset(B)
# Explique qué verifica este método y determine cuál sería el valor que devuelve al ejecutarse con los
# conjuntos que usted definió. Haga el mismo ejercicio con el método isdisjoint.

# %%
A1 = {"1", "2", "3", "4", "5"}
B1 = {"1", "2", "3"}

# %%
A1.issuperset(B1)
# Out:
# True

# %%
print(A1.isdisjoint(B1))
# Out:
# False

# %% [markdown]
# A1.issuperset(B1) lo q hace es confirmar si todos los elementos de B estan contenidos en A y en este caso si es asi y print(A1.isdisjoint(B1)) determina si no hay elementos en comun

# %% [markdown]
# **Instrucción 3:** Defina un diccionario llamado datos2 con al menos dos pares clave:valor de su
# elección. Posteriormente utilice la siguiente instrucción de Python:
# datos2.update({...})
# donde el argumento interior (...) corresponde a un nuevo diccionario.
# Explique qué hace el método update. Modifique el valor de una clave existente utilizando este
# método ¿Qué ocurre si agrega una clave:valor repetida?

# %%
datos2 = {"a":1, "b":2, "c":3, "d":4}

# %%
datos2.update({"e":5, "f":6})
datos2
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}

# %%
datos2.update({"e":2, "c":1})
datos2
# Out:
# {'a': 1, 'b': 2, 'c': 1, 'd': 4, 'e': 2, 'f': 6}

# %% [markdown]
# datos2.update({...}) lo q hace es actualizar el diccionario agregando mas claves con valores q se le indiquen. Y al agregar una clave con valor repetido simplemente va seguir actualizando el diccionario por encima del anterior

# %% [markdown]
# **Instrucción 4:** Defina un diccionario llamado datos3 con al menos dos pares clave:valor de su
# elección. Posteriormente implemente la siguiente instrucción de Python:
# datos3.setdefault(clave, valor)
# donde clave, valor corresponden a una clave y a un valor que no existen en su diccionario.
# Explique qué hace el método setdefault ¿Qué hace el método si anota una clave del diccionario,
# pero con un valor diferente? ¿Qué ocurre si agrega una clave:valor repetida?

# %%
datos3 = {"a":1, "b":2, "c":3, "d":4}
datos3
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
datos3.setdefault("e", 5)
datos3
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %% [markdown]
# Al colocar .setdefault con una clave y valor q no existen lo q hace es agregarlo al nuevo diccionario

# %%
datos3.setdefault("b", 8)
datos3
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %% [markdown]
# Pero si lo colocamos con una clave del diccionario pero con diferente valor lo deja como el primer diccionario predeterminado sin cambiarle nada

# %%
datos3.setdefault("c", 3)
datos3
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %% [markdown]
# y pasa exactaente lo mismo con al aplicarlo co una clave y valor q ya estan en el diccionario lo deja tal cual sin aplicarle algun cambio

# %% [markdown]
# Parte III

# %% [markdown]
# Codigo 1

# %%
m = 5
if isinstance(m, int) and m >= 0:
 for n in range(0, (m+1)):
   if n == 1 or n == 0:
    print("El número es ", n)
   else:
    for x in range(2, n):
     if n % x == 0:
      print(n, 'es igual a', x, '*', n // x)
      break
    else: # Este else corresponde al for, no al if
     print(n, 'es un número primo')
else:
 print("El número no es natural")
# Out:
# El número es  0
# El número es  1
# 2 es un número primo
# 3 es un número primo
# 4 es igual a 2 * 2
# 5 es un número primo
